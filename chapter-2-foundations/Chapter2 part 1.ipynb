# %%
from qiskit import QuantumRegister, QuantumCircuit
reg = QuantumRegister(1)
circuit = QuantumCircuit(reg)

display(circuit.draw('mpl',  initial_state=True))

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
vector = Statevector(circuit)
display(plot_bloch_multivector(vector.data))

# %%
from qiskit import QuantumRegister, QuantumCircuit
reg1 = QuantumRegister(1)
circ = QuantumCircuit(reg1)
circ.x(reg1[0])

display(circ.draw('mpl',  initial_state=True))

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
vector = Statevector(circ)
display(plot_bloch_multivector(vector.data))

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

circuit = QuantumCircuit(1)
circuit.h(0)                 # کیوبیت را وارد برهم‌نهی می‌کند: |0⟩ → (|0⟩+|1⟩)/√2
circuit.measure_all()
device = AerSimulator()
job = device.run(circuit, backend = device, shots = 1000)
print(job.job_id())
result = job.result()
counts = result.get_counts(circuit)
print(counts)
display(plot_histogram(counts))
# Out:
# c6be1c12-aeae-4d3e-a0dd-0be0a49f3da3
# {'0': 505, '1': 495}

# %%
from qiskit import QuantumRegister, QuantumCircuit
reg2 = QuantumRegister(1)
circ1 = QuantumCircuit(reg2)
circ1.x(reg2[0])
circ1.h(reg2[0])

display(circuit.draw('mpl',  initial_state=True))

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
vector = Statevector(circ1)
display(plot_bloch_multivector(vector.data))

# %%
from qiskit import QuantumRegister, QuantumCircuit
reg2 = QuantumRegister(1)
circ2 = QuantumCircuit(reg2)
circ2.h(reg2[0])

display(circ2.draw('mpl',  initial_state=True))

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
vector = Statevector(circ2)
display(plot_bloch_multivector(vector.data))
